# %%
import MMS_package as mms
from sympy import symbols, cos, pi
import matplotlib.pyplot as plt
import os
current_working_directory = os.getcwd()
if current_working_directory.endswith('Titans_TT_codecomparison'):
    os.chdir('MMS')
plt.rcParams["text.latex.preamble"]

#plt.rcParams['text.usetex'] = False
x, y, t = symbols("x y t")
fun = (2 + cos(2 * pi * x) * cos(2 * pi * y)) * t
fun2 = (1+cos(2*pi*x)*cos(2*pi*y))*t

mms.plotfun(fun,K=10,n_lines=4,filename="MS10s.txt",mms=True)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
mms.plotfun(fun2,K=10,n_lines=4,filename="Ver10s.txt",mms=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 mms.plotfun(fun2,K=10,n_lines=4,filename="Ver10s.txt",mms=False)
#
# File ~/Titans_TT_codecomparison/MMS/MMS_package.py:132, in plotfun(fun, K, filename, n_lines, mms)
#     130 else:
#     131     plt.savefig("MMS_M_1.png", dpi=300)
# --> 132 COMS = np.loadtxt(filename)
#     133 # Split the data into x, y, and color
#     134 x_COMS = COMS[:, 0]
#
# File ~/miniconda3/envs/festim-review-env/lib/python3.11/site-packages/numpy/lib/npyio.py:1356, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1353 if isinstance(delimiter, bytes):
#    1354     delimiter = delimiter.decode('latin1')
# -> 1356 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
# ...
